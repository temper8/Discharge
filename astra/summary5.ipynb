# %% [markdown]
# ## Саммари по экспериментру.
# В этом блoкноте собраны настроки астры и параметры рейтресинга.
# и результирующие траектории

# %%
import astra
astra.summary()
# Out:
#  ======  ASTRA summary =====
# Astra folder  D:\cygwin64\home\tmp8\ASTRA-6\a4
# exp file      40167exp_01
# equ file      40167equ_01

# %%
import ray_tracing
ray_tracing.summary()
# Out:
#  ====================  Ray tracing summary ====================
# Physical parameters                  hmin1     1e-06                     maxstep2  1000
# Freq      0.6                        rrange    0.0001                    maxstep4  1000
# xmi1      2.0                        eps       1e-06                     Options
# zi1       1.0                        hdrob     1.5                       ipri      2
# xmi2      16.0                       cleft     0.7                       iw        -1
# zi2       8.0                        cright    1.5                       ismth     0
# dni2      0.03                       cdel      0.25                      ismthalf  0
# xmi3      1.0                        rbord     0.999                     ismthout  1
# zi3       1.0                        pchm      0.2                       inew      0
# dni3      0.0                        pabs      0.01                      itor      1
# Parameters for alphas calculations   pgiter    0.0001                    ipol      1
# itend0    0                          ni1       20                        grill parameters and input LH spectrum
# energy    30.0                       ni2       20                        Zplus     11
# factor    1.0                        niterat   99                        Zminus    -11
# dra       0.3                        nmaxm(1)  20                        ntet      21
# kv        30                         nmaxm(2)  20                        nnz       51
# Numerical parameters                 nmaxm(3)  20
# nr        30                         nmaxm(4)  20

# %%
ray_tracing.plot_spectrum()

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1800734701609074.dat")
# Out:
# Number of traj 609   Max N_traj 1050

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1801734701598408.dat")
# Out:
# Number of traj 609   Max N_traj 1050

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1899734700553165.dat")
# Out:
# file out/traj.1899734700553165.dat not exits
