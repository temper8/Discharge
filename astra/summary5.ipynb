# %% [markdown]
# ## Саммари по экспериментру.
# В этом блoкноте собраны настроки астры и параметры рейтресинга.
# и результирующие траектории

# %%
import astra
astra.summary()
# Out:
#  ======  ASTRA summary =====
# Astra folder  D:\cygwin64\home\tmp8\ASTRA-6\a4
# exp file      40167exp_01
# equ file      40167equ_01

# %%
import ray_tracing
ray_tracing.summary4()
# Out:
#  ====================  Ray tracing summary ====================
#  ====== Physical parameters ======
# Freq      0.6                        zi2       8.0                       dni3      0.0
# xmi1      2.0                        dni2      0.03
# zi1       1.0                        xmi3      1.0
# xmi2      16.0                       zi3       1.0
#  ====== Parameters for alphas calculations ======
# itend0    0                          factor    1.0                       kv        30
# energy    30.0                       dra       0.3
#  ====== Numerical parameters ======
# nr        30                         rbord     0.999                     nmaxm(2)  20
# hmin1     1e-06                      pchm      0.2                       nmaxm(3)  20
# rrange    0.0001                     pabs      0.01                      nmaxm(4)  20
# eps       1e-06                      pgiter    0.0001                    maxstep2  1000
# hdrob     1.5                        ni1       20                        maxstep4  1000
# cleft     0.7                        ni2       20
# cright    1.5                        niterat   99
# cdel      0.25                       nmaxm(1)  20
#  ====== Options ======
# ipri      2                          ismthalf  0                         itor      1
# iw        -1.0                       ismthout  1                         ipol      1
# ismth     0                          inew      0.0
#  ====== grill parameters and input LH spectrum ======
# Zplus     11                         ntet      21
# Zminus    -11                        nnz       51

# %%
ray_tracing.plot_spectrum()

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1800734701609074.dat")
# Out:
# Number of traj 902   Max N_traj 1065

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1801734701598408.dat")
# Out:
# Number of traj 902   Max N_traj 1065

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1899734700553165.dat")
# Out:
# Number of traj 903   Max N_traj 1065
