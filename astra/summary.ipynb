# %% [markdown]
# ## Саммари по экспериментру.
# В этом блoкноте собраны настроки астры и параметры рейтресинга.
# и результирующие траектории

# %%
import summary
summary.widget()

# %%
summary.info()
# Out:
# race_2021_10_04_00_56_40.zip
#  ======  ASTRA summary =====
# Astra folder  D:\cygwin64\home\tmp8\ASTRA-6\a4
# exp file      40167_01.exp
# equ file      40167_01.equ

# %%
import race
R1 = race.Race(summary.race_file)
print(len(R1.traj_list))
print(summary.R1.traj_list[1])
# Out:
# init
# 100
# lhcd/out/traj.1801734705943335.dat

# %%
from zipfile import ZipFile
f = summary.R1.traj_list[1]
print(f)
with ZipFile('races/'+ R1.file) as zip:
    with zip.open(f) as file:
        line = file.readline().decode("utf-8").replace('=', '_').split() 
        print(line)
# Out:
# lhcd/out/traj.1801734705943335.dat
# ['R', 'Z', 'rho', 'theta', 'N_par', 'N_pol', 'P_tot', 'P_land', 'P_coll', 'vth', 'slow_1', 'out_1', 'N_traj']

# %%
R1.plot_trajectories(R1.traj_list[3])
# Out:
# Number of traj 273   Max N_traj 1034
# lhcd/out/traj.1803734705943335.dat

# %%
R1.few_plot_trajectories([5,57,98])
# Out:
# Number of traj 273   Max N_traj 1034
# lhcd/out/traj.1805734705943334.dat
# Number of traj 273   Max N_traj 1034
# lhcd/out/traj.1857734705943329.dat
# Number of traj 273   Max N_traj 1034
# lhcd/out/traj.1898734705943324.dat

# %%
from ipywidgets import interactive

def plot_func(index):
    R1.plot_trajectories(R1.traj_list[index])
 
w = interactive(plot_func, index = (1, len(R1.traj_list)))
w
# Out:
# interactive(children=(IntSlider(value=50, description='index', min=1), Output()), _dom_classes=('widget-intera…

# %%
import astra
astra.summary()
# Out:
#  ======  ASTRA summary =====
# Astra folder  D:\cygwin64\home\tmp8\ASTRA-6\a4
# exp file      40167_01.exp
# equ file      40167_02.equ

# %%
import ray_tracing
ray_tracing.summary()
# Out:
#  ====================  Ray tracing summary ====================
# Physical parameters                  rrange    0.0001                    Options
# Freq      1.0                        eps       1e-06                     ipri      2
# xmi1      2.0                        hdrob     1.5                       iw        -1
# zi1       1.0                        cleft     0.7                       ismth     0
# xmi2      16.0                       cright    1.5                       ismthalf  0
# zi2       8.0                        cdel      0.25                      ismthout  1
# dni2      0.03                       rbord     0.999                     inew      0
# xmi3      1.0                        pchm      0.2                       itor      1
# zi3       1.0                        pabs      0.01                      ipol      1
# dni3      0.0                        pgiter    0.0001                    grill parameters
# ...

# %%
ray_tracing.plot_spectrum()

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1800734701609074.dat")
# Out:
# Number of traj 462   Max N_traj 1044

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1801734701598408.dat")
# Out:
# Number of traj 462   Max N_traj 1044

# %%
import matplotlib.pyplot as plt
import numpy as np
import ray_tracing
ray_tracing.plot("out/traj.1803734701577077.dat")
# Out:
# Number of traj 462   Max N_traj 1044
