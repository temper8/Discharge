# %% [markdown]
# ## Саммари по экспериментру.
# В этом блoкноте собраны настроки астры и параметры рейтресинга.
# и результирующие траектории

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
module_path = os.path.abspath(os.path.join('..', 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import summary
summary.widget()
# Out:
# VBox(children=(Label(value='Select race :', layout=Layout(width='100%')), HBox(children=(SelectMultiple(descri…

# %%
summary.print_info(['Freq', 'xmi2', 'inew'])
# Out:
#            Zen5_2021_10_12_03_42_36.zip                      Zen5_2021_10_13_02_35_08.zip
#  ================= ASTRA summary ================= ================= ASTRA summary =================
#  Astra folder  D:\cygwin64\home\tmp8\ASTRA-6\a4    Astra folder  D:\cygwin64\home\tmp8\ASTRA-6\a4
#  exp file      40167_01.exp                        exp file      40167_01.exp
#  equ file      40167_01.equ                        equ file      40167_01.equ
#  Computer name  Zen5                               Computer name  Zen5
#  ============= Ray tracing parameters ============= ============= Ray tracing parameters =============
#  Freq:  0.6 (GHz)                                  Freq:  0.6 (GHz)
#  xmi2:  16.0 (Mi2/Mp)                              xmi2:  16.0 (Mi2/Mp)
#  inew:  1 (int)                                    inew:  1 (int)

# %%
from race import Race 
R1 = Race(summary.selected_races[0])
print(len(R1.traj_list))
print(R1.traj_list[1])
#R1.print_summary()
R2 = Race(summary.selected_races[0])
print(len(R2.traj_list))
print(R2.traj_list[1])
#R2.print_summary()
# Out:
# 4
# lhcd/out/traj.1801734705943335.dat
# 4
# lhcd/out/traj.1801734705943335.dat

# %%
# %matplotlib widget
R1.plot_trajectories(R1.traj_list[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
R1.plot(axs[0], 0)
R2.plot(axs[1], 0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from ipywidgets import interactive

def plot_func(index):
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))
    fig.suptitle(R1.traj_list[index-1])
    R1.plot(axs[0], index-1)
    R2.plot(axs[1], index-1)
    plt.show()
 
w = interactive(plot_func, index = (1, len(R1.traj_list)))
w
# Out:
# interactive(children=(IntSlider(value=2, description='index', max=4, min=1), Output()), _dom_classes=('widget-…

# %%
from ipywidgets import interactive

def plot_func(index):
    R1.plot_trajectories(R1.traj_list[index-1])
 
w = interactive(plot_func, index = (1, len(R1.traj_list)))
w
# Out:
# interactive(children=(IntSlider(value=16, description='index', max=31, min=1), Output()), _dom_classes=('widge…
